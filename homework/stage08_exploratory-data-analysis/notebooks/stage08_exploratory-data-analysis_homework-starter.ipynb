# %% [markdown]
# # Homework Starter — Stage 08 EDA
#
# Fill in the marked TODOs. This notebook generates synthetic data so you can focus on the EDA flow. Replace with your dataset when ready.

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from scipy.stats import skew, kurtosis
sns.set(context='talk', style='whitegrid')
np.random.seed(8)
pd.set_option('display.max_columns', 100)

# === Synthetic data generator (adapt or replace with your own data) ===
n = 160
df = pd.DataFrame({
    'date': pd.date_range('2021-02-01', periods=n, freq='D'),
    'region': np.random.choice(['North','South','East','West'], size=n),
    'age': np.random.normal(40, 8, size=n).clip(22, 70).round(1),
    'income': np.random.lognormal(mean=10.6, sigma=0.3, size=n).round(2),
    'transactions': np.random.poisson(lam=3, size=n),
})
base = df['income'] * 0.0015 + df['transactions']*18 + np.random.normal(0, 40, size=n)
df['spend'] = np.maximum(0, base).round(2)

# inject a bit of missingness and outliers
df.loc[np.random.choice(df.index, 5, replace=False), 'income'] = np.nan
df.loc[np.random.choice(df.index, 3, replace=False), 'spend'] = np.nan
df.loc[np.random.choice(df.index, 2, replace=False), 'transactions'] = df['transactions'].max()+12
df.head()
# Out:
#         date region   age    income  transactions   spend
# 0 2021-02-01   West  37.6  28086.81             4   73.35
# 1 2021-02-02  North  43.0  33034.75             1   52.37
# 2 2021-02-03  South  38.2  50045.39             2  131.85
# 3 2021-02-04  South  24.9  39467.28             4  147.58
# 4 2021-02-05  South  59.8  31201.65             1   86.76

# %% [markdown]
# ## 1) First look

# %%
df.info(), df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          160 non-null    datetime64[ns]
#  1   region        160 non-null    object
#  2   age           160 non-null    float64
#  3   income        155 non-null    float64
#  4   transactions  160 non-null    int64
#  5   spend         157 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 7.6+ KB
# (None,
#  date            0
#  region          0
#  age             0
#  income          5
#  transactions    0
#  spend           3
#  dtype: int64)

# %% [markdown]
# ## 2) Numeric profile

# %%
desc = df[['age','income','transactions','spend']].describe().T
desc['skew'] = [skew(df[c].dropna()) for c in desc.index]
desc['kurtosis'] = [kurtosis(df[c].dropna()) for c in desc.index]
desc
# Out:
#               count          mean           std       min       25%       50%  \
# age           160.0     40.018750      8.458676     22.00     34.70     40.15
# income        155.0  41983.866323  13262.457038  17928.80  32471.53  39332.52
# transactions  160.0      3.237500      2.585610      0.00      2.00      3.00
# spend         157.0    117.291592     51.768645      0.54     77.25    119.32
#
#                     75%       max      skew   kurtosis
# age              44.925     61.10  0.069538  -0.080125
# income        49697.690  87052.40  0.993336   0.918722
# transactions      4.000     20.00  3.466078  19.984802
# spend           153.340    280.05  0.130860  -0.084917

# %% [markdown]
# ## 3) Distributions (TODO: add at least 3)

# %%
# TODO: histogram + KDE for a key variable
sns.histplot(df['income'], kde=True)
plt.title('Income Distribution')
plt.show()

# TODO: boxplot for outliers
sns.boxplot(x=df['transactions'])
plt.title('Transactions (Outliers)')
plt.show()

# TODO: time series plot based on lecture
daily = df.set_index('date')[['transactions','spend']].resample('W').sum()
daily.plot(subplots=True, figsize=(10,6), title=['Weekly Transactions','Weekly Spend'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4) Relationships (TODO: add at least 2)

# %%
sns.scatterplot(data=df, x='income', y='spend', hue='region')
plt.title('Income vs Spend')
plt.show()

sns.scatterplot(data=df, x='age', y='spend')
plt.title('Age vs Spend')
plt.show()

sns.scatterplot(data=df, x='age', y='income')
plt.title('Age vs Income')
plt.show()

sns.scatterplot(data=df, x='income', y='transactions')
plt.title('Income vs Transactions')
plt.show()

sns.scatterplot(data=df, x='transactions', y='region')
plt.title('Transactions vs Region')
plt.show()

# %% [markdown]
# ## 5) (Optional) Correlation matrix

# %%
corr = df[['age','income','transactions','spend']].corr(numeric_only=True)
sns.heatmap(corr, annot=True, fmt='.2f', cmap='vlag', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
corr
# Out:
#                    age    income  transactions     spend
# age           1.000000 -0.123160      0.037754  0.008174
# income       -0.123160  1.000000      0.063573  0.307307
# transactions  0.037754  0.063573      1.000000  0.480685
# spend         0.008174  0.307307      0.480685  1.000000

# %% [markdown]
# ## 6) Insights & Assumptions (write your commentary)
#
# ## Insights
#  - Judging by the Correlaiton matrix there are two strong relationships, transcactions and spending (which makes sense as transactions are proportional to spending) and income and transactions. Income and transactions makes sense since a higher income person has more spending power than a lower income person. However, this isn't completely linear or anything because the highest transactions are not with teh highest incomes and the density of medium - high transactions are at 40000 rather than 60000-80000. This indicates that there isi a minijmum income for this generous spending that slightly increases as income increases, but not very much.
# - Age and income are not related. They have a negative value in the correlation matrix and the plot shows no correlation. Therefore, it cannot be assumed, at least for this dataset.
# - Though region is not seen in the correlation matrix, it is evident that there seems to be a link between transaction patterns and the region as the North region has less high transactions than the others, and South and West each ahve one very hgih spender each. This can make sense in the real world as location, and the GDP of the area can affect income and therefore transactions; also the availability of transactions (such as clothing, other nonessentials assuming essentials are around the same wherever) is affected too.
#
# ## Assumptions/Risks
# - Data Quality is good, with only random missing data.
# - Outliers are actual people, not bad data
# - Very simple assumption in that spend and transactions are related, though the only mitigating factor would be the case where there are too many small transactions that don't avffect spend enough.
# - Overfitting is a risk, there is a really small sample size so any trained model will bias features and the data might be incorrect for larger populations.
# - Time is only set for 5 months, there will be risks for predicting periods outside of this range.
#
# ## Next steps before modeling
# - Data Cleaning will be done using techniques from before (winsorization or iqr)
# - Using plots like this there will be outliers accounted for based on the information.
#
# ## Features
# - Age, income are definitely good featuers as there si a large range for age and income should affect the spend/transactions
# - Time based forecasting to account for seasonal tendencies, also rolling averages for other things like paaycheck releases (7, 14, 30 day)
